# %%
import requests

# %%
requests.get('https://ygn5at2pt5zgycacip4t6kvrey0ayfrl.lambda-url.us-east-2.on.aws//waiver_wire/725907041763303424/1049754172834455552').json()
# Out:
# [{'id_sleeper': '6904',
#   'full_name': 'Jalen Hurts',
#   'age': 25.0,
#   'team': 'PHI',
#   'number': '1',
#   'position': 'QB',
#   'week_of_season': '1',
#   'predicted_fantasy_points': 23.410000013560058,
#   'owner_id': '725907041763303424',
#   'owner_name': 'dirtywizard',
#   'team_name': 'Croccity Body Snatchers',
#   'is_user': True},
#  {'id_sleeper': '6904',
#   'full_name': 'Jalen Hurts',
#   'age': 25.0,
#   'team': 'PHI',
#   'number': '1',
#   'position': 'QB',
#   'week_of_season': '1',
#   'predicted_fantasy_points': 23.410000013560058,
#   'owner_id': '725907041763303424',
#   'owner_name': 'dirtywizard',
#   'team_name': 'Croccity Body Snatchers',
#   'is_user': True},
#  {'id_sleeper': '6904',
#   'full_name': 'Jalen Hurts',
#   'age': 25.0,
#   'team': 'PHI',
#   'number': '1',
#   'position': 'QB',
#   'week_of_season': '14',
#   'predicted_fantasy_points': 23.330000013858083,
#   'owner_id': '725907041763303424',
#   'owner_name': 'dirtywizard',
# ...
